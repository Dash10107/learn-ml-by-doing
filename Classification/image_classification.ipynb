# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Load the CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# Preprocess the data
x_train = x_train / 255.0
x_test = x_test / 255.0

# Define the model
model = keras.Sequential([
    layers.Input(shape=(32, 32, 3)),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step
# Epoch 1/10
# 1563/1563 [==============================] - 60s 38ms/step - loss: 1.4779 - accuracy: 0.4710 - val_loss: 1.2435 - val_accuracy: 0.5653
# Epoch 2/10
# 1563/1563 [==============================] - 57s 36ms/step - loss: 1.1695 - accuracy: 0.5888 - val_loss: 1.1218 - val_accuracy: 0.6068
# Epoch 3/10
# 1563/1563 [==============================] - 57s 37ms/step - loss: 1.0466 - accuracy: 0.6344 - val_loss: 1.0877 - val_accuracy: 0.6204
# Epoch 4/10
# 1563/1563 [==============================] - 57s 36ms/step - loss: 0.9663 - accuracy: 0.6615 - val_loss: 1.0842 - val_accuracy: 0.6202
# Epoch 5/10
# 1563/1563 [==============================] - 54s 35ms/step - loss: 0.8974 - accuracy: 0.6875 - val_loss: 1.0416 - val_accuracy: 0.6432
# Epoch 6/10
# 1563/1563 [==============================] - 59s 38ms/step - loss: 0.8409 - accuracy: 0.7083 - val_loss: 1.0539 - val_accuracy: 0.6438
# Epoch 7/10
# 1563/1563 [==============================] - 57s 37ms/step - loss: 0.7922 - accuracy: 0.7242 - val_loss: 1.0281 - val_accuracy: 0.6490
# Epoch 8/10
# 1563/1563 [==============================] - 55s 35ms/step - loss: 0.7479 - accuracy: 0.7355 - val_loss: 1.0324 - val_accuracy: 0.6497
# Epoch 9/10
# 1563/1563 [==============================] - 57s 36ms/step - loss: 0.7080 - accuracy: 0.7515 - val_loss: 1.0655 - val_accuracy: 0.6452
# Epoch 10/10
# 1563/1563 [==============================] - 57s 36ms/step - loss: 0.6651 - accuracy: 0.7680 - val_loss: 1.1058 - val_accuracy: 0.6367

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'sample_data']

# %%
# Save the model to an HDF5 file
model.save("my_model.h5")

# Verify that the file has been saved in the current directory
import os
os.listdir()
# Out:
# ['.config', 'my_model.h5', 'sample_data']

# %%
from google.colab import files

# Provide the filename you want to download
file_to_download = "my_model.h5"

# Use the files.download() function to initiate the download
files.download(file_to_download)
